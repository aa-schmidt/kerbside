# %% [markdown]
# ### Session set up

# %% [markdown]
# Import required modules

# %%
import pandas as pd
import re

# %% [markdown]
# ### Read in and format data

# %% [markdown]
# Read in data from [Brisbane City Council](https://www.brisbane.qld.gov.au/clean-and-green/rubbish-tips-and-bins/rubbish-collections/kerbside-large-item-collection-service) (kerbside collection 2025-26, data from BCC open data), [QGSO](https://www.qgso.qld.gov.au/geographies-maps/concordances/place-names-concordance) (Place Names Concordance 2022, used under CC-BY), and [ABS](https://www.abs.gov.au/statistics/people/people-and-communities/socio-economic-indexes-areas-seifa-australia/2021) (SEIFA SA2 Indexes, used under CC-BY). Index of Relative Socio-economic Advantage and Disadvantage used as interested in areas that have high access to material and social resources.

# %%
kerbside = pd.read_csv("../data/kerbside-large-item-collection-schedule 2025-26.csv", usecols=["Suburb", "Date of Collection"])
place_concord = pd.read_excel("../data/place-names-concordance-2022-edn.xlsx", sheet_name = "Place Names Concordance 2022")
seifa_21 = pd.read_excel("../data/Statistical Area Level 2, Indexes, SEIFA 2021.xlsx", sheet_name = "Table 3", skiprows = 4)

# %% [markdown]
# Check data read in as expected

# %%
kerbside.head()
# Out:
#          Suburb Date of Collection
# 0      ALGESTER         2025-07-14
# 1     CALAMVALE         2025-07-14
# 2     PARKINSON         2025-07-14
# 3       TARINGA         2025-07-21
# 4  AUCHENFLOWER         2025-07-21

# %%
place_concord.head()
# Out:
#     Place name (2021) Alternative place name (2021) Place type (2021)  \
# 0             A Creek                           NaN              STRM
# 1             A Creek                           NaN              STRM
# 2        A Flat Creek                           NaN              STRM
# 3           A W Creek                           NaN              STRM
# 4  Aarons Folly Gully                           NaN              STRM
#
#    Place name longitude (GDA2020)  Place name latitude (GDA2020)  \
# 0                      151.584442                     -24.648333
# 1                      151.200000                     -25.500000
# 2                      152.317146                     -26.374427
# 3                      142.949720                     -13.003610
# 4                      148.666670                     -21.800000
#
#     Suburb (2022)  Postcode (2019)  LGA code (2021)     LGA name (2021)  \
# 0        Gindoran             4676            33360       Gladstone (R)
# 1      Coonambula             4626            35760   North Burnett (R)
# 2        Manumbar             4601            33620          Gympie (R)
# 3  Lockhart River             4892            34570  Lockhart River (S)
# 4     Strathfield             4742            33980           Isaac (R)
#
#    SA1 code (2016)  ...  CED name (2019) ILOC code (2021)  \
# 0      30805153006  ...            Flynn         30500602
# 1      31902150304  ...            Flynn         30500803
# 2      31903151506  ...         Wide Bay         30601101
# 3      31501139615  ...       Leichhardt         30300601
# 4      31201133807  ...      Capricornia         30500703
#
#           ILOC name (2021) IARE code (2021)    IARE name (2021)  \
# 0  Gladstone - South Coast           305006           Gladstone
# 1    North Burnett - Rural           305008       North Burnett
# 2       Nanango - Kilkivan           306011  Nanango - Kilkivan
# 3           Lockhart River           303006      Lockhart River
# 4          Nebo - Clermont           305007     Nebo - Clermont
#
#   IREG code (2021)  IREG name (2021) UCL code (2021)  \
# 0              305       Rockhampton          331001
# 1              305       Rockhampton          331001
# 2              306  Toowoomba - Roma          331001
# 3              303         Cape York          331001
# 4              305       Rockhampton          331001
#
#                       UCL name (2021)  HHS name (2015)
# 0  Remainder of State/Territory (Qld)         Wide Bay
# 1  Remainder of State/Territory (Qld)         Wide Bay
# 2  Remainder of State/Territory (Qld)   Sunshine Coast
# 3  Remainder of State/Territory (Qld)  Torres and Cape
# 4  Remainder of State/Territory (Qld)           Mackay
#
# [5 rows x 48 columns]

# %% [markdown]
# Update names that will be on output

# %%
place_concord.rename(columns={"Place name (2021)": "suburb"
                             , "SA2 code (2021)": "sa2_21_code"}
                    , inplace=True)

# %%
kerbside.rename(columns={"Suburb": "suburb"
                         , "Date of Collection": "collection_date"}
                , inplace=True)

# %%
seifa_21.head()
# Out:
#                                           Unnamed: 0  \
# 0  2021 Statistical Area Level 2  (SA2) 9-Digit Code
# 1                                          101021007
# 2                                          101021008
# 3                                          101021009
# 4                                          101021010
#
#                                   Unnamed: 1                 Unnamed: 2  \
# 0  2021 Statistical Area Level 2 (SA2) Name   Usual Resident Population
# 1                                  Braidwood                       4343
# 2                                    Karabar                       8517
# 3                                 Queanbeyan                      11342
# 4                          Queanbeyan - East                       5085
#
#     Unnamed: 3  Unnamed: 4 Ranking within Australia Unnamed: 6  Unnamed: 7  \
# 0        Score         NaN                     Rank     Decile  Percentile
# 1  1000.677063         NaN                     1219          6          52
# 2   982.313373         NaN                     1029          5          44
# 3   998.123224         NaN                     1193          6          51
# 4  1014.994386         NaN                     1357          6          58
#
#    Unnamed: 8 Ranking within State or Territory Unnamed: 10 Unnamed: 11  \
# 0         NaN                             State        Rank      Decile
# 1         NaN                               NSW         306           5
# 2         NaN                               NSW         274           5
# 3         NaN                               NSW         301           5
# 4         NaN                               NSW         341           6
#
#   Unnamed: 12                     Unnamed: 13                     Unnamed: 14  \
# 0  Percentile  Minimum score for SA1s in area  Maximum score for SA1s in area
# 1          49                       948.45379                     1072.300317
# 2          44                      752.918555                     1115.451518
# 3          49                       926.97065                     1080.489718
# 4          55                      927.615874                     1136.308168
#
#                                          Unnamed: 15
# 0  % Usual Resident Population without an SA1 lev...
# 1                                                  0
# 2                                                  0
# 3                                           0.001587
# 4                                           0.006686

# %% [markdown]
# Make required updates to data for easier referencing. Will only rename columns to be kept in code.

# %%
seifa_21.rename(
    columns={"Unnamed: 0": "sa2_21_code"
            , "Unnamed: 1": "sa2_21_name"
            , "Ranking within State or Territory": "state"
            , "Unnamed: 10": "state_rank"
            , "Unnamed: 11": "state_decile"
            , "Unnamed: 12": "state_percentile"
            , "Unnamed: 13": "min_sa1_score"
            , "Unnamed: 14": "max_sa1_score"}
    , inplace=True
)
seifa_21.dropna(subset=["sa2_21_name"], how = "all", inplace=True)

# %% [markdown]
# Confirm through visual inspection that the desired columns and names have been updated.

# %%
seifa_21.tail()
# Out:
#      sa2_21_code              sa2_21_name Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 2349   801111141                  Namadgi         63  932.283577         NaN
# 2350   901011001         Christmas Island       1692  972.374332         NaN
# 2351   901021002  Cocos (Keeling) Islands        593  903.126462         NaN
# 2352   901031003               Jervis Bay        310  905.141211         NaN
# 2353   901041004           Norfolk Island       2188  957.778736         NaN
#
#      Ranking within Australia Unnamed: 6 Unnamed: 7  Unnamed: 8 state  \
# 2349                      527          3         23         NaN   ACT
# 2350                      934          4         40         NaN    OT
# 2351                      288          2         13         NaN    OT
# 2352                      303          2         13         NaN    OT
# 2353                      799          4         34         NaN    OT
#
#      state_rank state_decile state_percentile min_sa1_score max_sa1_score  \
# 2349          2            1                2    932.283577    932.283577
# 2350        NaN          NaN              NaN    952.023988   1011.096241
# 2351        NaN          NaN              NaN    842.198729    1082.17939
# 2352        NaN          NaN              NaN    783.240038   1064.184148
# 2353        NaN          NaN              NaN    918.656647    990.531554
#
#      Unnamed: 15
# 2349           0
# 2350    0.199173
# 2351    0.023609
# 2352    0.035484
# 2353    0.003199

# %% [markdown]
# Reduce SEIFA information to just QLD for more reliable matching as there are duplicate localities within and outside QLD. Also confirm that data filtered correctly by checking that the first digit of SA2 is 3 (ABS state code for QLD).

# %%
seifa_21 = seifa_21[seifa_21["state"] == "QLD"]
all((seifa_21["sa2_21_code"] >= 300000000) & (seifa_21["sa2_21_code"] < 400000000))
# Out:
# True

# %% [markdown]
# Reduce place name concordance to just Brisbane localities. The SA2 code on the file is tied to the place name column. Place name will be used to add on the SA2 code for the scraped Kerbside list.

# %%
place_concord = place_concord[place_concord["LGA code (2021)"] == 31000]

# %% [markdown]
# ### Clean data

# %% [markdown]
# There were some suburbs that had malformed coordinates that spanned over to the next row. Inspect and remove if no other information on that line.

# %%
kerbside["suburb"] = kerbside["suburb"].str.title()

# %% [markdown]
# Identify if there are any localities that don't share the same name. Want to match kerbside suburbs against the SEIFA deciles based on locality name.

# %%
locality_check = kerbside["suburb"].isin(place_concord["suburb"])
kerbside[~locality_check]
# Out:
#         suburb collection_date
# 9       Chuwar      2025-07-28
# 39   Macgregor      2025-09-01
# 70      Albion      2025-10-27
# 79       Ascot      2025-11-03
# 90    Mcdowall      2025-12-01
# 108    The Gap      2026-02-02
# 120   Red Hill      2026-02-16
# 147   West End      2026-04-20
# 172  Mackenzie      2026-06-08

# %% [markdown]
# Identify why these names don't match to the list of Kerbside collection suburbs

# %%
missing_localities = place_concord["suburb"].str.contains("chuwar|macgregor|albion|ascot|mcdowall|gap|red hill|west end|mackenzie", flags=re.IGNORECASE)
place_concord[missing_localities]
# Out:
#                           suburb Alternative place name (2021)  \
# 210       Albion (Brisbane City)                           NaN
# 787        Ascot (Brisbane City)                           NaN
# 6656      Chuwar (Brisbane City)                           NaN
# 12238                  Gap Creek                           NaN
# 18735                  MacGregor                           NaN
# 18766  Mackenzie (Brisbane City)                           NaN
# 19529                   McDowall                           NaN
# 27359   Red Hill (Brisbane City)                           NaN
# 32747    The Gap (Brisbane City)                           NaN
# 35608   West End (Brisbane City)                           NaN
#
#       Place type (2021)  Place name longitude (GDA2020)  \
# 210                 SUB                      153.044170
# 787                 SUB                      153.063890
# 6656               LOCB                      152.772780
# 12238              STRM                      152.915584
# 18735               SUB                      153.075830
# 18766               SUB                      153.130280
# 19529               SUB                      152.993890
# 27359               SUB                      153.003890
# 32747               SUB                      152.944440
# 35608               SUB                      153.006670
#
#        Place name latitude (GDA2020) Suburb (2022)  Postcode (2019)  \
# 210                       -27.433610        Albion             4010
# 787                       -27.429720         Ascot             4007
# 6656                      -27.549170        Chuwar             4306
# 12238                     -27.497826    Brookfield             4069
# 18735                     -27.565000     MacGregor             4109
# 18766                     -27.535830     Mackenzie             4156
# 19529                     -27.378890      McDowall             4053
# 27359                     -27.451110      Red Hill             4059
# 32747                     -27.441670       The Gap             4061
# 35608                     -27.483060      West End             4101
#
#        LGA code (2021) LGA name (2021)  SA1 code (2016)  ...  CED name (2019)  \
# 210              31000    Brisbane (C)      30503111913  ...         Brisbane
# 787              31000    Brisbane (C)      30503112112  ...         Brisbane
# 6656             31000    Brisbane (C)      31003128811  ...            Blair
# 12238            31000    Brisbane (C)      30402108714  ...             Ryan
# 18735            31000    Brisbane (C)      30303106110  ...          Moreton
# 18766            31000    Brisbane (C)      30303106401  ...           Bonner
# 19529            31000    Brisbane (C)      30201102610  ...           Lilley
# 27359            31000    Brisbane (C)      30504113609  ...         Brisbane
# 32747            31000    Brisbane (C)      30404110309  ...             Ryan
# 35608            31000    Brisbane (C)      30501111208  ...         Griffith
#
#       ILOC code (2021)                  ILOC name (2021) IARE code (2021)  \
# 210           30100203  Brisbane City - Inner North-West           301002
# 787           30100203  Brisbane City - Inner North-West           301002
# 6656          30100209        Brisbane City - Outer West           301002
# 12238         30100209        Brisbane City - Outer West           301002
# 18735         30100208       Brisbane City - Outer South           301002
# 18766         30100212        Brisbane City - Outer East           301002
# 19529         30100207       Brisbane City - Outer North           301002
# 27359         30100202       Brisbane City - Inner North           301002
# 32747         30100207       Brisbane City - Outer North           301002
# 35608         30100204       Brisbane City - Inner South           301002
#
#        IARE name (2021) IREG code (2021) IREG name (2021) UCL code (2021)  \
# 210       Brisbane City              301         Brisbane          301001
# 787       Brisbane City              301         Brisbane          301001
# 6656      Brisbane City              301         Brisbane          331001
# 12238     Brisbane City              301         Brisbane          301001
# 18735     Brisbane City              301         Brisbane          301001
# 18766     Brisbane City              301         Brisbane          331001
# 19529     Brisbane City              301         Brisbane          301001
# 27359     Brisbane City              301         Brisbane          301001
# 32747     Brisbane City              301         Brisbane          301001
# 35608     Brisbane City              301         Brisbane          301001
#
#                           UCL name (2021) HHS name (2015)
# 210                              Brisbane     Metro North
# 787                              Brisbane     Metro North
# 6656   Remainder of State/Territory (Qld)    West Moreton
# 12238                            Brisbane     Metro North
# 18735                            Brisbane     Metro South
# 18766  Remainder of State/Territory (Qld)     Metro South
# 19529                            Brisbane     Metro North
# 27359                            Brisbane     Metro North
# 32747                            Brisbane     Metro North
# 35608                            Brisbane     Metro South
#
# [10 rows x 48 columns]

# %% [markdown]
# Remove text in brackets so the place names match to the Kerbside localities.
# MacGregor and McDowall will need to be updated to all lower case to match the kerbside file.

# %%
place_concord["suburb"] = place_concord["suburb"].str.replace("\\(.+\\)", "", regex=True)
#place_concord["suburb"] = place_concord["suburb"].str.replace(r"\bMt\b", "Mount", regex=True)
place_concord.loc[place_concord["suburb"] == "MacGregor", "suburb"] = "Macgregor"
place_concord.loc[place_concord["suburb"] == "McDowall", "suburb"] = "Mcdowall"
place_concord["suburb"] = place_concord["suburb"].str.strip()

# %% [markdown]
# Repeat check to confirm that place names were updated correctly

# %%
locality_check = kerbside["suburb"].isin(place_concord["suburb"])
kerbside[~locality_check]
# Out:
# Empty DataFrame
# Columns: [suburb, collection_date]
# Index: []

# %% [markdown]
# Combine kerbside locality information with place concordance locality information to get the SA2 code for each area. SA2 code required for SEIFA decile. Left join used as all suburbs in the kerbside list should be kept for completion.

# %%
kerbside_sa2 = kerbside.merge(place_concord, on="suburb", how="left")

# %% [markdown]
# Confirm that merge was successful

# %%
print(kerbside_sa2.head(10))
print(kerbside_sa2.dtypes)
print(kerbside_sa2.shape)
# Out:
#            suburb collection_date Alternative place name (2021)  \
# 0        Algester      2025-07-14                           NaN
# 1       Calamvale      2025-07-14                           NaN
# 2       Parkinson      2025-07-14                           NaN
# 3         Taringa      2025-07-21                           NaN
# 4    Auchenflower      2025-07-21                           NaN
# 5        St Lucia      2025-07-21                           NaN
# 6          Milton      2025-07-21                           NaN
# 7  Pinjarra Hills      2025-07-28                           NaN
# 8      Bellbowrie      2025-07-28                           NaN
# 9          Chuwar      2025-07-28                           NaN
#
#   Place type (2021)  Place name longitude (GDA2020)  \
# 0               SUB                       153.03361
# 1               SUB                       153.04806
# 2               SUB                       153.02917
# 3               SUB                       152.98444
# 4               SUB                       152.99389
# 5               SUB                       153.00944
# 6               SUB                       153.00667
# 7               SUB                       152.90611
# 8               SUB                       152.88250
# 9              LOCB                       152.77278
#
#    Place name latitude (GDA2020)   Suburb (2022)  Postcode (2019)  \
# 0                      -27.61250        Algester             4115
# 1                      -27.62333       Calamvale             4116
# 2                      -27.64361       Parkinson             4115
# 3                      -27.49278         Taringa             4068
# 4                      -27.47333    Auchenflower             4066
# 5                      -27.49833        St Lucia             4072
# 6                      -27.46778          Milton             4064
# 7                      -27.53806  Pinjarra Hills             4069
# 8                      -27.55889      Bellbowrie             4070
# 9                      -27.54917          Chuwar             4306
#
#    LGA code (2021) LGA name (2021)  ...  CED name (2019)  ILOC code (2021)  \
# 0            31000    Brisbane (C)  ...           Rankin          30100208
# 1            31000    Brisbane (C)  ...           Rankin          30100208
# 2            31000    Brisbane (C)  ...           Rankin          30100208
# 3            31000    Brisbane (C)  ...             Ryan          30100203
# 4            31000    Brisbane (C)  ...             Ryan          30100203
# 5            31000    Brisbane (C)  ...             Ryan          30100203
# 6            31000    Brisbane (C)  ...         Brisbane          30100202
# 7            31000    Brisbane (C)  ...             Ryan          30100209
# 8            31000    Brisbane (C)  ...             Ryan          30100209
# 9            31000    Brisbane (C)  ...            Blair          30100209
#
#                    ILOC name (2021)  IARE code (2021) IARE name (2021)  \
# 0       Brisbane City - Outer South            301002    Brisbane City
# 1       Brisbane City - Outer South            301002    Brisbane City
# 2       Brisbane City - Outer South            301002    Brisbane City
# 3  Brisbane City - Inner North-West            301002    Brisbane City
# 4  Brisbane City - Inner North-West            301002    Brisbane City
# 5  Brisbane City - Inner North-West            301002    Brisbane City
# 6       Brisbane City - Inner North            301002    Brisbane City
# 7        Brisbane City - Outer West            301002    Brisbane City
# 8        Brisbane City - Outer West            301002    Brisbane City
# 9        Brisbane City - Outer West            301002    Brisbane City
#
#    IREG code (2021) IREG name (2021) UCL code (2021)  \
# 0               301         Brisbane          301001
# 1               301         Brisbane          301001
# 2               301         Brisbane          301001
# 3               301         Brisbane          301001
# 4               301         Brisbane          301001
# 5               301         Brisbane          301001
# 6               301         Brisbane          301001
# 7               301         Brisbane          301001
# 8               301         Brisbane          301001
# 9               301         Brisbane          331001
#
#                       UCL name (2021)  HHS name (2015)
# 0                            Brisbane      Metro South
# 1                            Brisbane      Metro South
# 2                            Brisbane      Metro South
# 3                            Brisbane      Metro North
# 4                            Brisbane      Metro North
# 5                            Brisbane      Metro North
# 6                            Brisbane      Metro North
# 7                            Brisbane      Metro North
# 8                            Brisbane      Metro North
# 9  Remainder of State/Territory (Qld)     West Moreton
#
# [10 rows x 49 columns]
# suburb                             object
# collection_date                    object
# Alternative place name (2021)      object
# Place type (2021)                  object
# Place name longitude (GDA2020)    float64
# Place name latitude (GDA2020)     float64
# Suburb (2022)                      object
# Postcode (2019)                     int64
# LGA code (2021)                     int64
# LGA name (2021)                    object
# SA1 code (2016)                     int64
# SA2 code (2016)                     int64
# SA2 name (2016)                    object
# SA3 code (2016)                     int64
# SA3 name (2016)                    object
# SA4 code (2016)                     int64
# SA4 name (2016)                    object
# GCCSA code (2016)                  object
# GCCSA name (2016)                  object
# ILOC code (2016)                    int64
# ILOC name (2016)                   object
# IARE code (2016)                    int64
# IARE name (2016)                   object
# IREG code (2016)                    int64
# IREG name (2016)                   object
# RA code (2016)                      int64
# RA name (2016)                     object
# UCL code (2016)                     int64
# UCL name (2016)                    object
# SA1 code (2021)                     int64
# sa2_21_code                         int64
# SA2 name (2021)                    object
# SA3 code (2021)                     int64
# SA3 name (2021)                    object
# SA4 code (2021)                     int64
# SA4 name (2021)                    object
# GCCSA code (2021)                  object
# GCCSA name (2021)                  object
# SED name (2017)                    object
# CED name (2019)                    object
# ILOC code (2021)                    int64
# ILOC name (2021)                   object
# IARE code (2021)                    int64
# IARE name (2021)                   object
# IREG code (2021)                    int64
# IREG name (2021)                   object
# UCL code (2021)                     int64
# UCL name (2021)                    object
# HHS name (2015)                    object
# dtype: object
# (204, 49)

# %% [markdown]
# Check if any SA2 codes have been excluded from the SEIFA advantage/disadvantage index as SA2 will be used to combine the collection list with the SEIFA information.

# %%
chk = kerbside_sa2["sa2_21_code"].isin(seifa_21["sa2_21_code"])
print(kerbside_sa2[~chk][["suburb", "sa2_21_code"]])
print(seifa_21[seifa_21["sa2_21_name"].str.contains("Kholo|Lake Manchester|Pinkenba|Lytton")])
# Out:
#               suburb  sa2_21_code
# 11             Kholo    310021279
# 16   Lake Manchester    310021279
# 17   Lake Manchester    310021279
# 78          Pinkenba    302031036
# 142           Lytton    301031014
#      sa2_21_code            sa2_21_name Unnamed: 2   Unnamed: 3  Unnamed: 4  \
# 1175   302031037  Eagle Farm - Pinkenba       2076  1087.427601         NaN
#
#      Ranking within Australia Unnamed: 6 Unnamed: 7  Unnamed: 8 state  \
# 1175                     1965          9         84         NaN   QLD
#
#      state_rank state_decile state_percentile min_sa1_score max_sa1_score  \
# 1175        475            9               89    934.991758    1118.57369
#
#      Unnamed: 15
# 1175           0

# %% [markdown]
# Checking against the ABS community profiles supports updating the Kholo and Pinkenba to populated neighbouring SA2s

# %%
kerbside_sa2.loc[kerbside_sa2["suburb"] == "Pinkenba", "sa2_21_code"] = 302031037 #Eagle Farm - Pinkenba code
kerbside_sa2.loc[kerbside_sa2["suburb"] == "Kholo", "sa2_21_code"] = 310031290 #Karana Downs

# %% [markdown]
# Add the SEIFA deciles to the kerbside dates. Left join used as all suburbs in the kerbside list should be kept for completion.

# %%
kerbside_sa2 = kerbside_sa2.merge(seifa_21, on="sa2_21_code", how="left")

print(kerbside_sa2.head(10))
print(kerbside_sa2.dtypes)
print(kerbside_sa2.shape)

# %% [markdown]
# Check for any duplicates introduced from the merge

# %%
possible_duplicates = kerbside_sa2.duplicated(
    ["sa2_21_code", "suburb", "state_rank"]
    , keep = False)
kerbside_sa2.loc[possible_duplicates, ["suburb", "Postcode (2019)", "state_rank", "sa2_21_code"]]
# All true duplicates so first or last pattern doesn't matter
kerbside_sa2.drop_duplicates(["sa2_21_code", "suburb", "state_rank"], keep="first", inplace=True)

# %% [markdown]
# Manually drop the duplicates that don't share the same SA2 name. Using a string distance measure on the suburb against the SA2 name might be a way to improve this.

# %%
kerbside_sa2["key"] = kerbside_sa2["suburb"] + "~" + kerbside_sa2["sa2_21_code"].astype("str")

kerbside_sa2.loc[kerbside_sa2["suburb"].duplicated(keep=False)
    , ["suburb", "Postcode (2019)", "state_rank", "sa2_21_name", "key"]]
# Out:
#              suburb  Postcode (2019) state_rank                  sa2_21_name  \
# 18          Moggill             4069        530  Pinjarra Hills - Pullenvale
# 19          Moggill             4070        482         Bellbowrie - Moggill
# 43            Oxley             4074        215               Darra - Sumner
# 44            Oxley             4075        436                  Oxley (Qld)
# 91           Nundah             4017        423       Sandgate - Shorncliffe
# 92           Nundah             4012        417                       Nundah
# 94           Kedron             4031        470         Kedron - Gordon Park
# 95           Kedron             4032        429               Chermside West
# 138         Bulimba             4152        519                    Camp Hill
# 139         Bulimba             4171        527                      Bulimba
# 151        Tingalpa             4155        469            Belmont - Gumdale
# 152        Tingalpa             4173        356                     Tingalpa
# 165  South Brisbane             4101        466                Highgate Hill
# 166  South Brisbane             4101        478               South Brisbane
# 171    Yeerongpilly             4105        494                      Yeronga
# 172    Yeerongpilly             4113        301                      Runcorn
#
#                           key
# 18          Moggill~304021091
# 19          Moggill~304021086
# 43            Oxley~310011271
# 44            Oxley~310011275
# 91           Nundah~302041044
# 92           Nundah~302031040
# 94           Kedron~302021031
# 95           Kedron~302021029
# 138         Bulimba~303011047
# 139         Bulimba~305021114
# 151        Tingalpa~301011002
# 152        Tingalpa~301031018
# 165  South Brisbane~305011107
# 166  South Brisbane~305011110
# 171    Yeerongpilly~303021059
# 172    Yeerongpilly~303061078

# %%
keys_remove = pd.Series(["Moggill~304021091", "Oxley~310011271", "Nundah~302041044" 
                         , "Kedron~302021029", "Bulimba~303011047", "Tingalpa~301011002", "South Brisbane~305011107"
                         , "Yeerongpilly~303061078"])
kerbside_sa2 = kerbside_sa2.loc[~(kerbside_sa2["key"].isin(keys_remove))]

# %% [markdown]
# ### User requirements and export data

# %% [markdown]
# Beneficial to sort by date to know what suburbs are coming up

# %%
kerbside_sa2["collection_date"] = pd.to_datetime(kerbside_sa2["collection_date"], format = "%Y-%m-%d")
clean_kerb = kerbside_sa2.sort_values("collection_date")

# %% [markdown]
# Export as csv for quick sharing. In addition to state SA2 SEIFA, have kept the minimum and maximum SA1 scores to reflect the variability in suburbs level of advantage or disadvantage.

# %%
clean_kerb = clean_kerb[["suburb", "collection_date", "state_rank", "state_decile", "state_percentile", "min_sa1_score", "max_sa1_score"]]
clean_kerb.to_csv(
    "../data/kerbside collection 2025-26 with state seifa 2021 decile and rank.csv"
    , index=False
)
